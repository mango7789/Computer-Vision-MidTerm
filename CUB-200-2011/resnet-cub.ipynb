# %% [markdown]
# ### 1. Preliminray

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from itertools import product
from solver import train_resnet_with_cub
from solver import test_resnet_with_cub

DATA_PATH = os.path.join("data", "CUB_200_2011")

os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# %% [markdown]
# ### 2. Grid-Search Optimal Learning Rate

# %% [markdown]
# #### 2.1 Set the range of hyper-parameters

# %%
# set hyper-parameters here
num_epochs = [15]
fine_tuning_lrs = [5e-5, 1e-4, 5e-4]
output_lrs = [1e-3, 2e-3, 5e-3, 8e-3, 1e-2]

configurations = list(product(fine_tuning_lrs, output_lrs))

# %% [markdown]
# #### 2.2 Train

# %%
best_accs = []

# train with the pretrained model
for config in configurations:
    curr_best_acc = train_resnet_with_cub(num_epochs, fine_tuning_lr=config[0], output_lr=config[1])
    best_accs.extend(curr_best_acc)

best_acc = max(best_accs)    
best_fine_tune_lr, best_output_lr = None, None

# write the results into a txt file
with open('best_accuracy_lr.txt', 'w') as f:
    f.write("Configuration        Accuracy\n")
    f.write("=" * 30 + "\n")
    for config, accuracy in zip(configurations, best_accs):
        # find the best config
        if accuracy == best_acc and best_fine_tune_lr is None:
            best_fine_tune_lr, best_output_lr = config
        # write the training record into file 
        f.write("({:>7.5f}, {:>7.5f})   {:>8.6f}\n".format(config[0], config[1], accuracy))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 138MB/s]
# ======================================================================
# Training with configuration (0.00005, 0.00100)
# [Epoch  1 / 15], Training loss is 6.988053
# [Epoch  1 / 15], Validation loss is 6.522593, Top-5 accuracy is 0.035899, Top-1 accuracy is 0.007767
# [Epoch  2 / 15], Training loss is 5.983014
# [Epoch  2 / 15], Validation loss is 5.964954, Top-5 accuracy is 0.057473, Top-1 accuracy is 0.013635
# [Epoch  3 / 15], Training loss is 5.492842
# [Epoch  3 / 15], Validation loss is 5.580335, Top-5 accuracy is 0.089748, Top-1 accuracy is 0.023127
# [Epoch  4 / 15], Training loss is 5.079500
# [Epoch  4 / 15], Validation loss is 5.219078, Top-5 accuracy is 0.133241, Top-1 accuracy is 0.037107
# [Epoch  5 / 15], Training loss is 4.715111
# [Epoch  5 / 15], Validation loss is 4.890339, Top-5 accuracy is 0.182085, Top-1 accuracy is 0.057818
# [Epoch  6 / 15], Training loss is 4.351164
# [Epoch  6 / 15], Validation loss is 4.560553, Top-5 accuracy is 0.244046, Top-1 accuracy is 0.085951
# [Epoch  7 / 15], Training loss is 4.019405
# [Epoch  7 / 15], Validation loss is 4.265923, Top-5 accuracy is 0.301864, Top-1 accuracy is 0.112358
# [Epoch  8 / 15], Training loss is 3.713315
# [Epoch  8 / 15], Validation loss is 4.007579, Top-5 accuracy is 0.353987, Top-1 accuracy is 0.139800
# [Epoch  9 / 15], Training loss is 3.464251
# [Epoch  9 / 15], Validation loss is 3.771258, Top-5 accuracy is 0.409044, Top-1 accuracy is 0.168450
# [Epoch 10 / 15], Training loss is 3.210893
# [Epoch 10 / 15], Validation loss is 3.570863, Top-5 accuracy is 0.454090, Top-1 accuracy is 0.200725
# [Epoch 11 / 15], Training loss is 2.996566
# [Epoch 11 / 15], Validation loss is 3.372570, Top-5 accuracy is 0.500518, Top-1 accuracy is 0.231619
# [Epoch 12 / 15], Training loss is 2.785381
# [Epoch 12 / 15], Validation loss is 3.208636, Top-5 accuracy is 0.538143, Top-1 accuracy is 0.255091
# [Epoch 13 / 15], Training loss is 2.636819
# [Epoch 13 / 15], Validation loss is 3.071238, Top-5 accuracy is 0.570072, Top-1 accuracy is 0.280117
# [Epoch 14 / 15], Training loss is 2.483073
# [Epoch 14 / 15], Validation loss is 2.938276, Top-5 accuracy is 0.600449, Top-1 accuracy is 0.303763
# [Epoch 15 / 15], Training loss is 2.353434
# [Epoch 15 / 15], Validation loss is 2.826734, Top-5 accuracy is 0.625475, Top-1 accuracy is 0.321540
# ======================================================================
# Training with configuration (0.00005, 0.00200)
# [Epoch  1 / 15], Training loss is 6.697133
# [Epoch  1 / 15], Validation loss is 6.181295, Top-5 accuracy is 0.045910, Top-1 accuracy is 0.011046
# [Epoch  2 / 15], Training loss is 5.618486
# [Epoch  2 / 15], Validation loss is 5.555193, Top-5 accuracy is 0.091992, Top-1 accuracy is 0.023990
# [Epoch  3 / 15], Training loss is 5.011069
# [Epoch  3 / 15], Validation loss is 5.033711, Top-5 accuracy is 0.160683, Top-1 accuracy is 0.051087
# [Epoch  4 / 15], Training loss is 4.458173
# [Epoch  4 / 15], Validation loss is 4.542506, Top-5 accuracy is 0.244909, Top-1 accuracy is 0.087677
# [Epoch  5 / 15], Training loss is 3.979635
# [Epoch  5 / 15], Validation loss is 4.128386, Top-5 accuracy is 0.329306, Top-1 accuracy is 0.128064
# [Epoch  6 / 15], Training loss is 3.543361
# [Epoch  6 / 15], Validation loss is 3.756498, Top-5 accuracy is 0.412323, Top-1 accuracy is 0.171557
# [Epoch  7 / 15], Training loss is 3.180820
# [Epoch  7 / 15], Validation loss is 3.457498, Top-5 accuracy is 0.482050, Top-1 accuracy is 0.215395
# [Epoch  8 / 15], Training loss is 2.870304
# [Epoch  8 / 15], Validation loss is 3.208441, Top-5 accuracy is 0.541077, Top-1 accuracy is 0.254746
# [Epoch  9 / 15], Training loss is 2.635916
# [Epoch  9 / 15], Validation loss is 3.004804, Top-5 accuracy is 0.581118, Top-1 accuracy is 0.289610
# [Epoch 10 / 15], Training loss is 2.409386
# [Epoch 10 / 15], Validation loss is 2.831478, Top-5 accuracy is 0.622023, Top-1 accuracy is 0.320159
# [Epoch 11 / 15], Training loss is 2.231177
# [Epoch 11 / 15], Validation loss is 2.676050, Top-5 accuracy is 0.654470, Top-1 accuracy is 0.352261
# [Epoch 12 / 15], Training loss is 2.056615
# [Epoch 12 / 15], Validation loss is 2.554273, Top-5 accuracy is 0.680359, Top-1 accuracy is 0.374180
# [Epoch 13 / 15], Training loss is 1.938341
# [Epoch 13 / 15], Validation loss is 2.445424, Top-5 accuracy is 0.700380, Top-1 accuracy is 0.393683
# [Epoch 14 / 15], Training loss is 1.818020
# [Epoch 14 / 15], Validation loss is 2.352423, Top-5 accuracy is 0.719365, Top-1 accuracy is 0.411805
# [Epoch 15 / 15], Training loss is 1.716398
# [Epoch 15 / 15], Validation loss is 2.275943, Top-5 accuracy is 0.737142, Top-1 accuracy is 0.429928
# ======================================================================
# Training with configuration (0.00005, 0.00500)
# [Epoch  1 / 15], Training loss is 6.309062
# [Epoch  1 / 15], Validation loss is 5.648859, Top-5 accuracy is 0.093027, Top-1 accuracy is 0.024853
# [Epoch  2 / 15], Training loss is 4.857831
# [Epoch  2 / 15], Validation loss is 4.617432, Top-5 accuracy is 0.233172, Top-1 accuracy is 0.081809
# [Epoch  3 / 15], Training loss is 3.919656
# [Epoch  3 / 15], Validation loss is 3.872511, Top-5 accuracy is 0.392648, Top-1 accuracy is 0.159821
# [Epoch  4 / 15], Training loss is 3.209212
# [Epoch  4 / 15], Validation loss is 3.347053, Top-5 accuracy is 0.503452, Top-1 accuracy is 0.232827
# [Epoch  5 / 15], Training loss is 2.696058
# [Epoch  5 / 15], Validation loss is 2.966468, Top-5 accuracy is 0.592337, Top-1 accuracy is 0.295478
# [Epoch  6 / 15], Training loss is 2.305448
# [Epoch  6 / 15], Validation loss is 2.674700, Top-5 accuracy is 0.649810, Top-1 accuracy is 0.347428
# [Epoch  7 / 15], Training loss is 2.026927
# [Epoch  7 / 15], Validation loss is 2.482837, Top-5 accuracy is 0.694512, Top-1 accuracy is 0.382810
# [Epoch  8 / 15], Training loss is 1.801688
# [Epoch  8 / 15], Validation loss is 2.316099, Top-5 accuracy is 0.729720, Top-1 accuracy is 0.414049
# [Epoch  9 / 15], Training loss is 1.646228
# [Epoch  9 / 15], Validation loss is 2.204129, Top-5 accuracy is 0.747325, Top-1 accuracy is 0.436831
# [Epoch 10 / 15], Training loss is 1.490767
# [Epoch 10 / 15], Validation loss is 2.091957, Top-5 accuracy is 0.768899, Top-1 accuracy is 0.462030
# [Epoch 11 / 15], Training loss is 1.379218
# [Epoch 11 / 15], Validation loss is 2.014328, Top-5 accuracy is 0.777528, Top-1 accuracy is 0.479462
# [Epoch 12 / 15], Training loss is 1.267140
# [Epoch 12 / 15], Validation loss is 1.949312, Top-5 accuracy is 0.790645, Top-1 accuracy is 0.491888
# [Epoch 13 / 15], Training loss is 1.189405
# [Epoch 13 / 15], Validation loss is 1.880870, Top-5 accuracy is 0.808250, Top-1 accuracy is 0.504315
# [Epoch 14 / 15], Training loss is 1.112900
# [Epoch 14 / 15], Validation loss is 1.844864, Top-5 accuracy is 0.810839, Top-1 accuracy is 0.510356
# [Epoch 15 / 15], Training loss is 1.045960
# [Epoch 15 / 15], Validation loss is 1.814083, Top-5 accuracy is 0.815844, Top-1 accuracy is 0.519330
# ======================================================================
# Training with configuration (0.00005, 0.00800)
# [Epoch  1 / 15], Training loss is 6.074662
# [Epoch  1 / 15], Validation loss is 5.217232, Top-5 accuracy is 0.146703, Top-1 accuracy is 0.053331
# [Epoch  2 / 15], Training loss is 4.275467
# [Epoch  2 / 15], Validation loss is 3.987009, Top-5 accuracy is 0.362962, Top-1 accuracy is 0.148775
# [Epoch  3 / 15], Training loss is 3.227603
# [Epoch  3 / 15], Validation loss is 3.235072, Top-5 accuracy is 0.530721, Top-1 accuracy is 0.255609
# [Epoch  4 / 15], Training loss is 2.554556
# [Epoch  4 / 15], Validation loss is 2.805334, Top-5 accuracy is 0.622886, Top-1 accuracy is 0.318605
# [Epoch  5 / 15], Training loss is 2.110134
# [Epoch  5 / 15], Validation loss is 2.513148, Top-5 accuracy is 0.686227, Top-1 accuracy is 0.379358
# [Epoch  6 / 15], Training loss is 1.788124
# [Epoch  6 / 15], Validation loss is 2.289990, Top-5 accuracy is 0.729030, Top-1 accuracy is 0.421816
# [Epoch  7 / 15], Training loss is 1.569596
# [Epoch  7 / 15], Validation loss is 2.158398, Top-5 accuracy is 0.750259, Top-1 accuracy is 0.442699
# [Epoch  8 / 15], Training loss is 1.391322
# [Epoch  8 / 15], Validation loss is 2.035220, Top-5 accuracy is 0.775457, Top-1 accuracy is 0.469279
# [Epoch  9 / 15], Training loss is 1.271842
# [Epoch  9 / 15], Validation loss is 1.970897, Top-5 accuracy is 0.790128, Top-1 accuracy is 0.482741
# [Epoch 10 / 15], Training loss is 1.146394
# [Epoch 10 / 15], Validation loss is 1.878609, Top-5 accuracy is 0.801346, Top-1 accuracy is 0.508457
# [Epoch 11 / 15], Training loss is 1.061294
# [Epoch 11 / 15], Validation loss is 1.832010, Top-5 accuracy is 0.812565, Top-1 accuracy is 0.517432
# [Epoch 12 / 15], Training loss is 0.973819
# [Epoch 12 / 15], Validation loss is 1.780701, Top-5 accuracy is 0.816707, Top-1 accuracy is 0.524163
# [Epoch 13 / 15], Training loss is 0.907946
# [Epoch 13 / 15], Validation loss is 1.735941, Top-5 accuracy is 0.829479, Top-1 accuracy is 0.534346
# [Epoch 14 / 15], Training loss is 0.847044
# [Epoch 14 / 15], Validation loss is 1.722157, Top-5 accuracy is 0.830860, Top-1 accuracy is 0.538833
# [Epoch 15 / 15], Training loss is 0.790755
# [Epoch 15 / 15], Validation loss is 1.711924, Top-5 accuracy is 0.836900, Top-1 accuracy is 0.542630
# ======================================================================
# Training with configuration (0.00005, 0.01000)
# [Epoch  1 / 15], Training loss is 5.946862
# [Epoch  1 / 15], Validation loss is 4.966735, Top-5 accuracy is 0.187435, Top-1 accuracy is 0.067656
# [Epoch  2 / 15], Training loss is 3.966495
# [Epoch  2 / 15], Validation loss is 3.692639, Top-5 accuracy is 0.430445, Top-1 accuracy is 0.187953
# [Epoch  3 / 15], Training loss is 2.908388
# [Epoch  3 / 15], Validation loss is 2.982651, Top-5 accuracy is 0.580255, Top-1 accuracy is 0.295651
# [Epoch  4 / 15], Training loss is 2.280440
# [Epoch  4 / 15], Validation loss is 2.598277, Top-5 accuracy is 0.668795, Top-1 accuracy is 0.361236
# [Epoch  5 / 15], Training loss is 1.876498
# [Epoch  5 / 15], Validation loss is 2.350187, Top-5 accuracy is 0.717121, Top-1 accuracy is 0.412668
# [Epoch  6 / 15], Training loss is 1.584664
# [Epoch  6 / 15], Validation loss is 2.159167, Top-5 accuracy is 0.752330, Top-1 accuracy is 0.448740
# [Epoch  7 / 15], Training loss is 1.391216
# [Epoch  7 / 15], Validation loss is 2.052699, Top-5 accuracy is 0.769071, Top-1 accuracy is 0.467553
# [Epoch  8 / 15], Training loss is 1.231085
# [Epoch  8 / 15], Validation loss is 1.946327, Top-5 accuracy is 0.791336, Top-1 accuracy is 0.489127
# [Epoch  9 / 15], Training loss is 1.124899
# [Epoch  9 / 15], Validation loss is 1.901027, Top-5 accuracy is 0.802554, Top-1 accuracy is 0.498619
# [Epoch 10 / 15], Training loss is 1.011305
# [Epoch 10 / 15], Validation loss is 1.816967, Top-5 accuracy is 0.812047, Top-1 accuracy is 0.520193
# [Epoch 11 / 15], Training loss is 0.935635
# [Epoch 11 / 15], Validation loss is 1.779425, Top-5 accuracy is 0.819814, Top-1 accuracy is 0.530721
# [Epoch 12 / 15], Training loss is 0.856398
# [Epoch 12 / 15], Validation loss is 1.733309, Top-5 accuracy is 0.828271, Top-1 accuracy is 0.537625
# [Epoch 13 / 15], Training loss is 0.794780
# [Epoch 13 / 15], Validation loss is 1.698978, Top-5 accuracy is 0.836382, Top-1 accuracy is 0.545737
# [Epoch 14 / 15], Training loss is 0.740373
# [Epoch 14 / 15], Validation loss is 1.692750, Top-5 accuracy is 0.836728, Top-1 accuracy is 0.546255
# [Epoch 15 / 15], Training loss is 0.687943
# [Epoch 15 / 15], Validation loss is 1.690015, Top-5 accuracy is 0.840525, Top-1 accuracy is 0.547463
# ======================================================================
# Training with configuration (0.00010, 0.00100)
# [Epoch  1 / 15], Training loss is 6.918224
# [Epoch  1 / 15], Validation loss is 6.361596, Top-5 accuracy is 0.041940, Top-1 accuracy is 0.009838
# [Epoch  2 / 15], Training loss is 5.724428
# [Epoch  2 / 15], Validation loss is 5.654174, Top-5 accuracy is 0.083017, Top-1 accuracy is 0.020366
# [Epoch  3 / 15], Training loss is 5.073095
# [Epoch  3 / 15], Validation loss is 5.123373, Top-5 accuracy is 0.144805, Top-1 accuracy is 0.040387
# [Epoch  4 / 15], Training loss is 4.515924
# [Epoch  4 / 15], Validation loss is 4.638547, Top-5 accuracy is 0.227994, Top-1 accuracy is 0.078702
# [Epoch  5 / 15], Training loss is 4.036061
# [Epoch  5 / 15], Validation loss is 4.218061, Top-5 accuracy is 0.315326, Top-1 accuracy is 0.119434
# [Epoch  6 / 15], Training loss is 3.601961
# [Epoch  6 / 15], Validation loss is 3.848440, Top-5 accuracy is 0.394028, Top-1 accuracy is 0.165343
# [Epoch  7 / 15], Training loss is 3.236614
# [Epoch  7 / 15], Validation loss is 3.537375, Top-5 accuracy is 0.462720, Top-1 accuracy is 0.208146
# [Epoch  8 / 15], Training loss is 2.921844
# [Epoch  8 / 15], Validation loss is 3.290007, Top-5 accuracy is 0.523127, Top-1 accuracy is 0.242492
# [Epoch  9 / 15], Training loss is 2.682762
# [Epoch  9 / 15], Validation loss is 3.082393, Top-5 accuracy is 0.568519, Top-1 accuracy is 0.282706
# [Epoch 10 / 15], Training loss is 2.457551
# [Epoch 10 / 15], Validation loss is 2.917274, Top-5 accuracy is 0.607007, Top-1 accuracy is 0.311702
# [Epoch 11 / 15], Training loss is 2.270682
# [Epoch 11 / 15], Validation loss is 2.752894, Top-5 accuracy is 0.646186, Top-1 accuracy is 0.340697
# [Epoch 12 / 15], Training loss is 2.093431
# [Epoch 12 / 15], Validation loss is 2.628984, Top-5 accuracy is 0.670694, Top-1 accuracy is 0.363825
# [Epoch 13 / 15], Training loss is 1.977222
# [Epoch 13 / 15], Validation loss is 2.527728, Top-5 accuracy is 0.689852, Top-1 accuracy is 0.386262
# [Epoch 14 / 15], Training loss is 1.846832
# [Epoch 14 / 15], Validation loss is 2.428231, Top-5 accuracy is 0.711771, Top-1 accuracy is 0.405765
# [Epoch 15 / 15], Training loss is 1.742695
# [Epoch 15 / 15], Validation loss is 2.344095, Top-5 accuracy is 0.732309, Top-1 accuracy is 0.427684
# ======================================================================
# Training with configuration (0.00010, 0.00200)
# [Epoch  1 / 15], Training loss is 6.631682
# [Epoch  1 / 15], Validation loss is 6.028294, Top-5 accuracy is 0.055057, Top-1 accuracy is 0.012427
# [Epoch  2 / 15], Training loss is 5.374024
# [Epoch  2 / 15], Validation loss is 5.257687, Top-5 accuracy is 0.127373, Top-1 accuracy is 0.033656
# [Epoch  3 / 15], Training loss is 4.615564
# [Epoch  3 / 15], Validation loss is 4.599860, Top-5 accuracy is 0.236106, Top-1 accuracy is 0.082154
# [Epoch  4 / 15], Training loss is 3.945695
# [Epoch  4 / 15], Validation loss is 4.028150, Top-5 accuracy is 0.353642, Top-1 accuracy is 0.133241
# [Epoch  5 / 15], Training loss is 3.399658
# [Epoch  5 / 15], Validation loss is 3.581443, Top-5 accuracy is 0.452019, Top-1 accuracy is 0.199862
# [Epoch  6 / 15], Training loss is 2.952793
# [Epoch  6 / 15], Validation loss is 3.223196, Top-5 accuracy is 0.531930, Top-1 accuracy is 0.256472
# [Epoch  7 / 15], Training loss is 2.603366
# [Epoch  7 / 15], Validation loss is 2.944922, Top-5 accuracy is 0.597515, Top-1 accuracy is 0.299103
# [Epoch  8 / 15], Training loss is 2.318276
# [Epoch  8 / 15], Validation loss is 2.729090, Top-5 accuracy is 0.647912, Top-1 accuracy is 0.341388
# [Epoch  9 / 15], Training loss is 2.112784
# [Epoch  9 / 15], Validation loss is 2.562497, Top-5 accuracy is 0.679323, Top-1 accuracy is 0.377977
# [Epoch 10 / 15], Training loss is 1.920277
# [Epoch 10 / 15], Validation loss is 2.425931, Top-5 accuracy is 0.710045, Top-1 accuracy is 0.400414
# [Epoch 11 / 15], Training loss is 1.764527
# [Epoch 11 / 15], Validation loss is 2.297928, Top-5 accuracy is 0.734380, Top-1 accuracy is 0.430273
# [Epoch 12 / 15], Training loss is 1.618024
# [Epoch 12 / 15], Validation loss is 2.208381, Top-5 accuracy is 0.754229, Top-1 accuracy is 0.440283
# [Epoch 13 / 15], Training loss is 1.524276
# [Epoch 13 / 15], Validation loss is 2.125067, Top-5 accuracy is 0.767691, Top-1 accuracy is 0.461857
# [Epoch 14 / 15], Training loss is 1.419272
# [Epoch 14 / 15], Validation loss is 2.054897, Top-5 accuracy is 0.780980, Top-1 accuracy is 0.474111
# [Epoch 15 / 15], Training loss is 1.332868
# [Epoch 15 / 15], Validation loss is 1.995673, Top-5 accuracy is 0.788229, Top-1 accuracy is 0.487401
# ======================================================================
# Training with configuration (0.00010, 0.00500)
# [Epoch  1 / 15], Training loss is 6.249206
# [Epoch  1 / 15], Validation loss is 5.506642, Top-5 accuracy is 0.105454, Top-1 accuracy is 0.030549
# [Epoch  2 / 15], Training loss is 4.631463
# [Epoch  2 / 15], Validation loss is 4.337524, Top-5 accuracy is 0.283914, Top-1 accuracy is 0.105972
# [Epoch  3 / 15], Training loss is 3.580174
# [Epoch  3 / 15], Validation loss is 3.515402, Top-5 accuracy is 0.471004, Top-1 accuracy is 0.208146
# [Epoch  4 / 15], Training loss is 2.837817
# [Epoch  4 / 15], Validation loss is 3.001820, Top-5 accuracy is 0.577839, Top-1 accuracy is 0.289265
# [Epoch  5 / 15], Training loss is 2.337117
# [Epoch  5 / 15], Validation loss is 2.644310, Top-5 accuracy is 0.658785, Top-1 accuracy is 0.353124
# [Epoch  6 / 15], Training loss is 1.981878
# [Epoch  6 / 15], Validation loss is 2.392566, Top-5 accuracy is 0.710735, Top-1 accuracy is 0.401450
# [Epoch  7 / 15], Training loss is 1.725888
# [Epoch  7 / 15], Validation loss is 2.219501, Top-5 accuracy is 0.744909, Top-1 accuracy is 0.433725
# [Epoch  8 / 15], Training loss is 1.523536
# [Epoch  8 / 15], Validation loss is 2.078521, Top-5 accuracy is 0.773386, Top-1 accuracy is 0.464101
# [Epoch  9 / 15], Training loss is 1.384827
# [Epoch  9 / 15], Validation loss is 1.987668, Top-5 accuracy is 0.790300, Top-1 accuracy is 0.483604
# [Epoch 10 / 15], Training loss is 1.245838
# [Epoch 10 / 15], Validation loss is 1.892347, Top-5 accuracy is 0.806351, Top-1 accuracy is 0.504487
# [Epoch 11 / 15], Training loss is 1.143119
# [Epoch 11 / 15], Validation loss is 1.827119, Top-5 accuracy is 0.812392, Top-1 accuracy is 0.520538
# [Epoch 12 / 15], Training loss is 1.042998
# [Epoch 12 / 15], Validation loss is 1.776849, Top-5 accuracy is 0.822575, Top-1 accuracy is 0.525716
# [Epoch 13 / 15], Training loss is 0.975527
# [Epoch 13 / 15], Validation loss is 1.721056, Top-5 accuracy is 0.833448, Top-1 accuracy is 0.542975
# [Epoch 14 / 15], Training loss is 0.903305
# [Epoch 14 / 15], Validation loss is 1.692629, Top-5 accuracy is 0.836555, Top-1 accuracy is 0.546600
# [Epoch 15 / 15], Training loss is 0.840102
# [Epoch 15 / 15], Validation loss is 1.667120, Top-5 accuracy is 0.842251, Top-1 accuracy is 0.553158
# ======================================================================
# Training with configuration (0.00010, 0.00800)
# [Epoch  1 / 15], Training loss is 6.017480
# [Epoch  1 / 15], Validation loss is 5.075736, Top-5 accuracy is 0.167242, Top-1 accuracy is 0.060062
# [Epoch  2 / 15], Training loss is 4.059247
# [Epoch  2 / 15], Validation loss is 3.723896, Top-5 accuracy is 0.424922, Top-1 accuracy is 0.180359
# [Epoch  3 / 15], Training loss is 2.939344
# [Epoch  3 / 15], Validation loss is 2.945148, Top-5 accuracy is 0.590266, Top-1 accuracy is 0.307042
# [Epoch  4 / 15], Training loss is 2.273910
# [Epoch  4 / 15], Validation loss is 2.548707, Top-5 accuracy is 0.681912, Top-1 accuracy is 0.367967
# [Epoch  5 / 15], Training loss is 1.853229
# [Epoch  5 / 15], Validation loss is 2.276509, Top-5 accuracy is 0.735243, Top-1 accuracy is 0.425785
# [Epoch  6 / 15], Training loss is 1.562727
# [Epoch  6 / 15], Validation loss is 2.087861, Top-5 accuracy is 0.769417, Top-1 accuracy is 0.461685
# [Epoch  7 / 15], Training loss is 1.357782
# [Epoch  7 / 15], Validation loss is 1.966764, Top-5 accuracy is 0.787711, Top-1 accuracy is 0.483259
# [Epoch  8 / 15], Training loss is 1.194751
# [Epoch  8 / 15], Validation loss is 1.858664, Top-5 accuracy is 0.812565, Top-1 accuracy is 0.507939
# [Epoch  9 / 15], Training loss is 1.085006
# [Epoch  9 / 15], Validation loss is 1.807871, Top-5 accuracy is 0.818088, Top-1 accuracy is 0.515188
# [Epoch 10 / 15], Training loss is 0.969027
# [Epoch 10 / 15], Validation loss is 1.726998, Top-5 accuracy is 0.830514, Top-1 accuracy is 0.537970
# [Epoch 11 / 15], Training loss is 0.887921
# [Epoch 11 / 15], Validation loss is 1.688799, Top-5 accuracy is 0.833794, Top-1 accuracy is 0.551605
# [Epoch 12 / 15], Training loss is 0.807393
# [Epoch 12 / 15], Validation loss is 1.647275, Top-5 accuracy is 0.841560, Top-1 accuracy is 0.557301
# [Epoch 13 / 15], Training loss is 0.747532
# [Epoch 13 / 15], Validation loss is 1.611147, Top-5 accuracy is 0.850362, Top-1 accuracy is 0.565412
# [Epoch 14 / 15], Training loss is 0.688933
# [Epoch 14 / 15], Validation loss is 1.599156, Top-5 accuracy is 0.850708, Top-1 accuracy is 0.568692
# [Epoch 15 / 15], Training loss is 0.634450
# [Epoch 15 / 15], Validation loss is 1.591244, Top-5 accuracy is 0.855022, Top-1 accuracy is 0.569900
# ======================================================================
# Training with configuration (0.00010, 0.01000)
# [Epoch  1 / 15], Training loss is 5.890566
# [Epoch  1 / 15], Validation loss is 4.825748, Top-5 accuracy is 0.207801, Top-1 accuracy is 0.076976
# [Epoch  2 / 15], Training loss is 3.757509
# [Epoch  2 / 15], Validation loss is 3.443827, Top-5 accuracy is 0.487746, Top-1 accuracy is 0.220746
# [Epoch  3 / 15], Training loss is 2.650491
# [Epoch  3 / 15], Validation loss is 2.725805, Top-5 accuracy is 0.638764, Top-1 accuracy is 0.340697
# [Epoch  4 / 15], Training loss is 2.039036
# [Epoch  4 / 15], Validation loss is 2.376022, Top-5 accuracy is 0.709182, Top-1 accuracy is 0.398688
# [Epoch  5 / 15], Training loss is 1.657921
# [Epoch  5 / 15], Validation loss is 2.143645, Top-5 accuracy is 0.760442, Top-1 accuracy is 0.449430
# [Epoch  6 / 15], Training loss is 1.393671
# [Epoch  6 / 15], Validation loss is 1.983725, Top-5 accuracy is 0.788057, Top-1 accuracy is 0.484812
# [Epoch  7 / 15], Training loss is 1.209834
# [Epoch  7 / 15], Validation loss is 1.884549, Top-5 accuracy is 0.804108, Top-1 accuracy is 0.500173
# [Epoch  8 / 15], Training loss is 1.061630
# [Epoch  8 / 15], Validation loss is 1.788187, Top-5 accuracy is 0.822748, Top-1 accuracy is 0.519676
# [Epoch  9 / 15], Training loss is 0.963142
# [Epoch  9 / 15], Validation loss is 1.752248, Top-5 accuracy is 0.826372, Top-1 accuracy is 0.528133
# [Epoch 10 / 15], Training loss is 0.855960
# [Epoch 10 / 15], Validation loss is 1.678326, Top-5 accuracy is 0.835347, Top-1 accuracy is 0.548671
# [Epoch 11 / 15], Training loss is 0.782983
# [Epoch 11 / 15], Validation loss is 1.648643, Top-5 accuracy is 0.840697, Top-1 accuracy is 0.561443
# [Epoch 12 / 15], Training loss is 0.709494
# [Epoch 12 / 15], Validation loss is 1.610739, Top-5 accuracy is 0.847083, Top-1 accuracy is 0.564895
# [Epoch 13 / 15], Training loss is 0.652621
# [Epoch 13 / 15], Validation loss is 1.582768, Top-5 accuracy is 0.855713, Top-1 accuracy is 0.571971
# [Epoch 14 / 15], Training loss is 0.600139
# [Epoch 14 / 15], Validation loss is 1.577238, Top-5 accuracy is 0.854332, Top-1 accuracy is 0.574215
# [Epoch 15 / 15], Training loss is 0.548934
# [Epoch 15 / 15], Validation loss is 1.576025, Top-5 accuracy is 0.860028, Top-1 accuracy is 0.575078
# ======================================================================
# Training with configuration (0.00050, 0.00100)
# [Epoch  1 / 15], Training loss is 6.404677
# [Epoch  1 / 15], Validation loss is 5.212830, Top-5 accuracy is 0.151363, Top-1 accuracy is 0.045564
# [Epoch  2 / 15], Training loss is 4.095971
# [Epoch  2 / 15], Validation loss is 3.745098, Top-5 accuracy is 0.417501, Top-1 accuracy is 0.182258
# [Epoch  3 / 15], Training loss is 2.953505
# [Epoch  3 / 15], Validation loss is 3.038628, Top-5 accuracy is 0.584743, Top-1 accuracy is 0.299448
# [Epoch  4 / 15], Training loss is 2.287903
# [Epoch  4 / 15], Validation loss is 2.644054, Top-5 accuracy is 0.675181, Top-1 accuracy is 0.377632
# [Epoch  5 / 15], Training loss is 1.864896
# [Epoch  5 / 15], Validation loss is 2.386999, Top-5 accuracy is 0.727822, Top-1 accuracy is 0.433379
# [Epoch  6 / 15], Training loss is 1.552900
# [Epoch  6 / 15], Validation loss is 2.189057, Top-5 accuracy is 0.762858, Top-1 accuracy is 0.467035
# [Epoch  7 / 15], Training loss is 1.316143
# [Epoch  7 / 15], Validation loss is 2.042336, Top-5 accuracy is 0.782361, Top-1 accuracy is 0.500518
# [Epoch  8 / 15], Training loss is 1.123140
# [Epoch  8 / 15], Validation loss is 1.950120, Top-5 accuracy is 0.800311, Top-1 accuracy is 0.513635
# [Epoch  9 / 15], Training loss is 0.981032
# [Epoch  9 / 15], Validation loss is 1.892525, Top-5 accuracy is 0.808595, Top-1 accuracy is 0.523818
# [Epoch 10 / 15], Training loss is 0.844940
# [Epoch 10 / 15], Validation loss is 1.830668, Top-5 accuracy is 0.816707, Top-1 accuracy is 0.540041
# [Epoch 11 / 15], Training loss is 0.734969
# [Epoch 11 / 15], Validation loss is 1.769912, Top-5 accuracy is 0.824128, Top-1 accuracy is 0.551087
# [Epoch 12 / 15], Training loss is 0.640659
# [Epoch 12 / 15], Validation loss is 1.745478, Top-5 accuracy is 0.828271, Top-1 accuracy is 0.553331
# [Epoch 13 / 15], Training loss is 0.575756
# [Epoch 13 / 15], Validation loss is 1.711441, Top-5 accuracy is 0.833966, Top-1 accuracy is 0.562996
# [Epoch 14 / 15], Training loss is 0.502139
# [Epoch 14 / 15], Validation loss is 1.693087, Top-5 accuracy is 0.835520, Top-1 accuracy is 0.568174
# [Epoch 15 / 15], Training loss is 0.449089
# [Epoch 15 / 15], Validation loss is 1.663499, Top-5 accuracy is 0.840179, Top-1 accuracy is 0.570590
# ======================================================================
# Training with configuration (0.00050, 0.00200)
# [Epoch  1 / 15], Training loss is 6.149722
# [Epoch  1 / 15], Validation loss is 4.939206, Top-5 accuracy is 0.177080, Top-1 accuracy is 0.056093
# [Epoch  2 / 15], Training loss is 3.848853
# [Epoch  2 / 15], Validation loss is 3.514659, Top-5 accuracy is 0.465827, Top-1 accuracy is 0.211943
# [Epoch  3 / 15], Training loss is 2.722459
# [Epoch  3 / 15], Validation loss is 2.830017, Top-5 accuracy is 0.631170, Top-1 accuracy is 0.332931
# [Epoch  4 / 15], Training loss is 2.079169
# [Epoch  4 / 15], Validation loss is 2.455360, Top-5 accuracy is 0.710908, Top-1 accuracy is 0.409044
# [Epoch  5 / 15], Training loss is 1.671769
# [Epoch  5 / 15], Validation loss is 2.216807, Top-5 accuracy is 0.753193, Top-1 accuracy is 0.464101
# [Epoch  6 / 15], Training loss is 1.381012
# [Epoch  6 / 15], Validation loss is 2.039090, Top-5 accuracy is 0.784950, Top-1 accuracy is 0.491716
# [Epoch  7 / 15], Training loss is 1.159637
# [Epoch  7 / 15], Validation loss is 1.910159, Top-5 accuracy is 0.803072, Top-1 accuracy is 0.520711
# [Epoch  8 / 15], Training loss is 0.984180
# [Epoch  8 / 15], Validation loss is 1.826358, Top-5 accuracy is 0.819814, Top-1 accuracy is 0.531757
# [Epoch  9 / 15], Training loss is 0.855347
# [Epoch  9 / 15], Validation loss is 1.779468, Top-5 accuracy is 0.822230, Top-1 accuracy is 0.541595
# [Epoch 10 / 15], Training loss is 0.728114
# [Epoch 10 / 15], Validation loss is 1.723061, Top-5 accuracy is 0.833103, Top-1 accuracy is 0.559372
# [Epoch 11 / 15], Training loss is 0.630252
# [Epoch 11 / 15], Validation loss is 1.674843, Top-5 accuracy is 0.837418, Top-1 accuracy is 0.563341
# [Epoch 12 / 15], Training loss is 0.546439
# [Epoch 12 / 15], Validation loss is 1.652231, Top-5 accuracy is 0.842768, Top-1 accuracy is 0.571453
# [Epoch 13 / 15], Training loss is 0.487950
# [Epoch 13 / 15], Validation loss is 1.619327, Top-5 accuracy is 0.845185, Top-1 accuracy is 0.578875
# [Epoch 14 / 15], Training loss is 0.425452
# [Epoch 14 / 15], Validation loss is 1.610182, Top-5 accuracy is 0.843286, Top-1 accuracy is 0.579220
# [Epoch 15 / 15], Training loss is 0.378485
# [Epoch 15 / 15], Validation loss is 1.585766, Top-5 accuracy is 0.846911, Top-1 accuracy is 0.583362
# ======================================================================
# Training with configuration (0.00050, 0.00500)
# [Epoch  1 / 15], Training loss is 5.803393
# [Epoch  1 / 15], Validation loss is 4.497134, Top-5 accuracy is 0.257680, Top-1 accuracy is 0.094408
# [Epoch  2 / 15], Training loss is 3.331448
# [Epoch  2 / 15], Validation loss is 3.003417, Top-5 accuracy is 0.586469, Top-1 accuracy is 0.281671
# [Epoch  3 / 15], Training loss is 2.229575
# [Epoch  3 / 15], Validation loss is 2.389229, Top-5 accuracy is 0.715050, Top-1 accuracy is 0.413876
# [Epoch  4 / 15], Training loss is 1.661190
# [Epoch  4 / 15], Validation loss is 2.107680, Top-5 accuracy is 0.771315, Top-1 accuracy is 0.466172
# [Epoch  5 / 15], Training loss is 1.310269
# [Epoch  5 / 15], Validation loss is 1.920116, Top-5 accuracy is 0.799103, Top-1 accuracy is 0.509493
# [Epoch  6 / 15], Training loss is 1.066930
# [Epoch  6 / 15], Validation loss is 1.783212, Top-5 accuracy is 0.822057, Top-1 accuracy is 0.535381
# [Epoch  7 / 15], Training loss is 0.880672
# [Epoch  7 / 15], Validation loss is 1.693970, Top-5 accuracy is 0.836728, Top-1 accuracy is 0.552123
# [Epoch  8 / 15], Training loss is 0.736522
# [Epoch  8 / 15], Validation loss is 1.635891, Top-5 accuracy is 0.845530, Top-1 accuracy is 0.569210
# [Epoch  9 / 15], Training loss is 0.633671
# [Epoch  9 / 15], Validation loss is 1.609160, Top-5 accuracy is 0.847083, Top-1 accuracy is 0.570763
# [Epoch 10 / 15], Training loss is 0.527181
# [Epoch 10 / 15], Validation loss is 1.562189, Top-5 accuracy is 0.856921, Top-1 accuracy is 0.585261
# [Epoch 11 / 15], Training loss is 0.452639
# [Epoch 11 / 15], Validation loss is 1.529861, Top-5 accuracy is 0.858302, Top-1 accuracy is 0.591819
# [Epoch 12 / 15], Training loss is 0.391205
# [Epoch 12 / 15], Validation loss is 1.516452, Top-5 accuracy is 0.865551, Top-1 accuracy is 0.599241
# [Epoch 13 / 15], Training loss is 0.340968
# [Epoch 13 / 15], Validation loss is 1.493825, Top-5 accuracy is 0.865033, Top-1 accuracy is 0.602865
# [Epoch 14 / 15], Training loss is 0.297169
# [Epoch 14 / 15], Validation loss is 1.488453, Top-5 accuracy is 0.864170, Top-1 accuracy is 0.603555
# [Epoch 15 / 15], Training loss is 0.261083
# [Epoch 15 / 15], Validation loss is 1.477731, Top-5 accuracy is 0.869348, Top-1 accuracy is 0.608215
# ======================================================================
# Training with configuration (0.00050, 0.00800)
# [Epoch  1 / 15], Training loss is 5.595562
# [Epoch  1 / 15], Validation loss is 4.134940, Top-5 accuracy is 0.333966, Top-1 accuracy is 0.133759
# [Epoch  2 / 15], Training loss is 2.956807
# [Epoch  2 / 15], Validation loss is 2.685984, Top-5 accuracy is 0.651018, Top-1 accuracy is 0.347774
# [Epoch  3 / 15], Training loss is 1.928223
# [Epoch  3 / 15], Validation loss is 2.147673, Top-5 accuracy is 0.756990, Top-1 accuracy is 0.458233
# [Epoch  4 / 15], Training loss is 1.421403
# [Epoch  4 / 15], Validation loss is 1.924787, Top-5 accuracy is 0.796859, Top-1 accuracy is 0.497239
# [Epoch  5 / 15], Training loss is 1.108541
# [Epoch  5 / 15], Validation loss is 1.767775, Top-5 accuracy is 0.822920, Top-1 accuracy is 0.536244
# [Epoch  6 / 15], Training loss is 0.891566
# [Epoch  6 / 15], Validation loss is 1.664657, Top-5 accuracy is 0.841905, Top-1 accuracy is 0.561098
# [Epoch  7 / 15], Training loss is 0.727768
# [Epoch  7 / 15], Validation loss is 1.598374, Top-5 accuracy is 0.846565, Top-1 accuracy is 0.571971
# [Epoch  8 / 15], Training loss is 0.602143
# [Epoch  8 / 15], Validation loss is 1.552148, Top-5 accuracy is 0.854505, Top-1 accuracy is 0.583535
# [Epoch  9 / 15], Training loss is 0.512096
# [Epoch  9 / 15], Validation loss is 1.530473, Top-5 accuracy is 0.861236, Top-1 accuracy is 0.588540
# [Epoch 10 / 15], Training loss is 0.418783
# [Epoch 10 / 15], Validation loss is 1.491162, Top-5 accuracy is 0.865723, Top-1 accuracy is 0.603383
# [Epoch 11 / 15], Training loss is 0.357526
# [Epoch 11 / 15], Validation loss is 1.468633, Top-5 accuracy is 0.866931, Top-1 accuracy is 0.604246
# [Epoch 12 / 15], Training loss is 0.310098
# [Epoch 12 / 15], Validation loss is 1.456550, Top-5 accuracy is 0.871591, Top-1 accuracy is 0.608733
# [Epoch 13 / 15], Training loss is 0.264311
# [Epoch 13 / 15], Validation loss is 1.443590, Top-5 accuracy is 0.874008, Top-1 accuracy is 0.613738
# [Epoch 14 / 15], Training loss is 0.232013
# [Epoch 14 / 15], Validation loss is 1.436426, Top-5 accuracy is 0.874008, Top-1 accuracy is 0.612875
# [Epoch 15 / 15], Training loss is 0.201840
# [Epoch 15 / 15], Validation loss is 1.433345, Top-5 accuracy is 0.877459, Top-1 accuracy is 0.618053
# ======================================================================
# Training with configuration (0.00050, 0.01000)
# [Epoch  1 / 15], Training loss is 5.481130
# [Epoch  1 / 15], Validation loss is 3.924461, Top-5 accuracy is 0.377977, Top-1 accuracy is 0.157577
# [Epoch  2 / 15], Training loss is 2.759579
# [Epoch  2 / 15], Validation loss is 2.549399, Top-5 accuracy is 0.679323, Top-1 accuracy is 0.372627
# [Epoch  3 / 15], Training loss is 1.783293
# [Epoch  3 / 15], Validation loss is 2.045697, Top-5 accuracy is 0.774422, Top-1 accuracy is 0.475147
# [Epoch  4 / 15], Training loss is 1.310192
# [Epoch  4 / 15], Validation loss is 1.847726, Top-5 accuracy is 0.812392, Top-1 accuracy is 0.511909
# [Epoch  5 / 15], Training loss is 1.016611
# [Epoch  5 / 15], Validation loss is 1.706180, Top-5 accuracy is 0.834311, Top-1 accuracy is 0.545737
# [Epoch  6 / 15], Training loss is 0.810399
# [Epoch  6 / 15], Validation loss is 1.621288, Top-5 accuracy is 0.847946, Top-1 accuracy is 0.567656
# [Epoch  7 / 15], Training loss is 0.657625
# [Epoch  7 / 15], Validation loss is 1.565100, Top-5 accuracy is 0.853297, Top-1 accuracy is 0.578357
# [Epoch  8 / 15], Training loss is 0.538850
# [Epoch  8 / 15], Validation loss is 1.520933, Top-5 accuracy is 0.858302, Top-1 accuracy is 0.590611
# [Epoch  9 / 15], Training loss is 0.457141
# [Epoch  9 / 15], Validation loss is 1.500239, Top-5 accuracy is 0.865033, Top-1 accuracy is 0.595789
# [Epoch 10 / 15], Training loss is 0.370520
# [Epoch 10 / 15], Validation loss is 1.464934, Top-5 accuracy is 0.869002, Top-1 accuracy is 0.608043
# [Epoch 11 / 15], Training loss is 0.314522
# [Epoch 11 / 15], Validation loss is 1.447082, Top-5 accuracy is 0.869348, Top-1 accuracy is 0.607698
# [Epoch 12 / 15], Training loss is 0.272316
# [Epoch 12 / 15], Validation loss is 1.435346, Top-5 accuracy is 0.875043, Top-1 accuracy is 0.617881
# [Epoch 13 / 15], Training loss is 0.230455
# [Epoch 13 / 15], Validation loss is 1.424790, Top-5 accuracy is 0.875734, Top-1 accuracy is 0.615809
# [Epoch 14 / 15], Training loss is 0.202821
# [Epoch 14 / 15], Validation loss is 1.419777, Top-5 accuracy is 0.875734, Top-1 accuracy is 0.618226
# [Epoch 15 / 15], Training loss is 0.175310
# [Epoch 15 / 15], Validation loss is 1.420294, Top-5 accuracy is 0.879531, Top-1 accuracy is 0.619261

# %% [markdown]
# #### 2.3 Inspect the Accuracy

# %%
# !more .\Output\best_accuracy_lr.txt
# Out:
# Configuration        Accuracy
# ==============================
# (0.00005, 0.00100)   0.321540
# (0.00005, 0.00200)   0.429928
# (0.00005, 0.00500)   0.519330
# (0.00005, 0.00800)   0.542630
# (0.00005, 0.01000)   0.547463
# (0.00010, 0.00100)   0.427684
# (0.00010, 0.00200)   0.487401
# (0.00010, 0.00500)   0.553158
# (0.00010, 0.00800)   0.569900
# (0.00010, 0.01000)   0.575078
# (0.00050, 0.00100)   0.570590
# (0.00050, 0.00200)   0.583362
# (0.00050, 0.00500)   0.608215
# (0.00050, 0.00800)   0.618053
# (0.00050, 0.01000)   0.619261

# %% [markdown]
# ### 3. Find the Optimal Training Epoch

# %% [markdown]
# #### 3.1 Train on a larger epoch

# %%
num_epochs = [5 * (i + 1) for i in range(9)]

# init the configurations
best_accs = []

# train with the pretrained model
curr_best_acc = train_resnet_with_cub(num_epochs, best_fine_tune_lr, best_output_lr, save=True)
best_accs.extend(curr_best_acc)
    
# write the results into a txt file
with open('best_accuracy_ep.txt', 'w') as f:
    f.write("Epoch  Accuracy\n")
    f.write("=" * 50 + "\n")
    for num_epoch, accuracy in zip(num_epochs, best_accs):
        f.write("{:>2}     {:>8.6f}\n".format(num_epoch, accuracy))
# Out:
# ======================================================================
# Training with configuration (0.00050, 0.01000)
# [Epoch  1 / 45], Training loss is 5.481130
# [Epoch  1 / 45], Validation loss is 3.924461, Top-5 accuracy is 0.377977, Top-1 accuracy is 0.157577
# [Epoch  2 / 45], Training loss is 2.759579
# [Epoch  2 / 45], Validation loss is 2.549399, Top-5 accuracy is 0.679323, Top-1 accuracy is 0.372627
# [Epoch  3 / 45], Training loss is 1.783293
# [Epoch  3 / 45], Validation loss is 2.045697, Top-5 accuracy is 0.774422, Top-1 accuracy is 0.475147
# [Epoch  4 / 45], Training loss is 1.310192
# [Epoch  4 / 45], Validation loss is 1.847726, Top-5 accuracy is 0.812392, Top-1 accuracy is 0.511909
# [Epoch  5 / 45], Training loss is 1.016611
# [Epoch  5 / 45], Validation loss is 1.706180, Top-5 accuracy is 0.834311, Top-1 accuracy is 0.545737
# [Epoch  6 / 45], Training loss is 0.810399
# [Epoch  6 / 45], Validation loss is 1.621288, Top-5 accuracy is 0.847946, Top-1 accuracy is 0.567656
# [Epoch  7 / 45], Training loss is 0.657625
# [Epoch  7 / 45], Validation loss is 1.565100, Top-5 accuracy is 0.853297, Top-1 accuracy is 0.578357
# [Epoch  8 / 45], Training loss is 0.538850
# [Epoch  8 / 45], Validation loss is 1.520933, Top-5 accuracy is 0.858302, Top-1 accuracy is 0.590611
# [Epoch  9 / 45], Training loss is 0.457141
# [Epoch  9 / 45], Validation loss is 1.500239, Top-5 accuracy is 0.865033, Top-1 accuracy is 0.595789
# [Epoch 10 / 45], Training loss is 0.370520
# [Epoch 10 / 45], Validation loss is 1.464934, Top-5 accuracy is 0.869002, Top-1 accuracy is 0.608043
# [Epoch 11 / 45], Training loss is 0.314522
# [Epoch 11 / 45], Validation loss is 1.447082, Top-5 accuracy is 0.869348, Top-1 accuracy is 0.607698
# [Epoch 12 / 45], Training loss is 0.272316
# [Epoch 12 / 45], Validation loss is 1.435346, Top-5 accuracy is 0.875043, Top-1 accuracy is 0.617881
# [Epoch 13 / 45], Training loss is 0.230455
# [Epoch 13 / 45], Validation loss is 1.424790, Top-5 accuracy is 0.875734, Top-1 accuracy is 0.615809
# [Epoch 14 / 45], Training loss is 0.202821
# [Epoch 14 / 45], Validation loss is 1.419777, Top-5 accuracy is 0.875734, Top-1 accuracy is 0.618226
# [Epoch 15 / 45], Training loss is 0.175310
# [Epoch 15 / 45], Validation loss is 1.420294, Top-5 accuracy is 0.879531, Top-1 accuracy is 0.619261
# [Epoch 16 / 45], Training loss is 0.158211
# [Epoch 16 / 45], Validation loss is 1.405492, Top-5 accuracy is 0.879358, Top-1 accuracy is 0.627373
# [Epoch 17 / 45], Training loss is 0.140231
# [Epoch 17 / 45], Validation loss is 1.406053, Top-5 accuracy is 0.877287, Top-1 accuracy is 0.629617
# [Epoch 18 / 45], Training loss is 0.122893
# [Epoch 18 / 45], Validation loss is 1.398212, Top-5 accuracy is 0.878495, Top-1 accuracy is 0.631170
# [Epoch 19 / 45], Training loss is 0.113204
# [Epoch 19 / 45], Validation loss is 1.396061, Top-5 accuracy is 0.880048, Top-1 accuracy is 0.629617
# [Epoch 20 / 45], Training loss is 0.100145
# [Epoch 20 / 45], Validation loss is 1.379553, Top-5 accuracy is 0.881602, Top-1 accuracy is 0.637038
# [Epoch 21 / 45], Training loss is 0.091460
# [Epoch 21 / 45], Validation loss is 1.378150, Top-5 accuracy is 0.880911, Top-1 accuracy is 0.633414
# [Epoch 22 / 45], Training loss is 0.087275
# [Epoch 22 / 45], Validation loss is 1.376355, Top-5 accuracy is 0.881256, Top-1 accuracy is 0.638246
# [Epoch 23 / 45], Training loss is 0.077902
# [Epoch 23 / 45], Validation loss is 1.368698, Top-5 accuracy is 0.881947, Top-1 accuracy is 0.639455
# [Epoch 24 / 45], Training loss is 0.078102
# [Epoch 24 / 45], Validation loss is 1.376946, Top-5 accuracy is 0.883328, Top-1 accuracy is 0.639282
# [Epoch 25 / 45], Training loss is 0.069990
# [Epoch 25 / 45], Validation loss is 1.368243, Top-5 accuracy is 0.884881, Top-1 accuracy is 0.637729
# [Epoch 26 / 45], Training loss is 0.063725
# [Epoch 26 / 45], Validation loss is 1.366852, Top-5 accuracy is 0.884536, Top-1 accuracy is 0.641008
# [Epoch 27 / 45], Training loss is 0.062976
# [Epoch 27 / 45], Validation loss is 1.370031, Top-5 accuracy is 0.885226, Top-1 accuracy is 0.641526
# [Epoch 28 / 45], Training loss is 0.056110
# [Epoch 28 / 45], Validation loss is 1.370596, Top-5 accuracy is 0.882119, Top-1 accuracy is 0.639282
# [Epoch 29 / 45], Training loss is 0.053955
# [Epoch 29 / 45], Validation loss is 1.364482, Top-5 accuracy is 0.885399, Top-1 accuracy is 0.639627
# [Epoch 30 / 45], Training loss is 0.053073
# [Epoch 30 / 45], Validation loss is 1.364486, Top-5 accuracy is 0.883328, Top-1 accuracy is 0.642734
# [Epoch 31 / 45], Training loss is 0.047675
# [Epoch 31 / 45], Validation loss is 1.359807, Top-5 accuracy is 0.886262, Top-1 accuracy is 0.644287
# [Epoch 32 / 45], Training loss is 0.044003
# [Epoch 32 / 45], Validation loss is 1.359194, Top-5 accuracy is 0.886089, Top-1 accuracy is 0.647912
# [Epoch 33 / 45], Training loss is 0.045285
# [Epoch 33 / 45], Validation loss is 1.354726, Top-5 accuracy is 0.887125, Top-1 accuracy is 0.646703
# [Epoch 34 / 45], Training loss is 0.045327
# [Epoch 34 / 45], Validation loss is 1.356628, Top-5 accuracy is 0.884881, Top-1 accuracy is 0.645323
# [Epoch 35 / 45], Training loss is 0.043648
# [Epoch 35 / 45], Validation loss is 1.364292, Top-5 accuracy is 0.882810, Top-1 accuracy is 0.643942
# [Epoch 36 / 45], Training loss is 0.043862
# [Epoch 36 / 45], Validation loss is 1.360154, Top-5 accuracy is 0.884536, Top-1 accuracy is 0.645668
# [Epoch 37 / 45], Training loss is 0.043939
# [Epoch 37 / 45], Validation loss is 1.354866, Top-5 accuracy is 0.885054, Top-1 accuracy is 0.643942
# [Epoch 38 / 45], Training loss is 0.042696
# [Epoch 38 / 45], Validation loss is 1.359750, Top-5 accuracy is 0.886952, Top-1 accuracy is 0.643942
# [Epoch 39 / 45], Training loss is 0.043987
# [Epoch 39 / 45], Validation loss is 1.352543, Top-5 accuracy is 0.886262, Top-1 accuracy is 0.646358
# [Epoch 40 / 45], Training loss is 0.041850
# [Epoch 40 / 45], Validation loss is 1.363815, Top-5 accuracy is 0.885399, Top-1 accuracy is 0.645323
# [Epoch 41 / 45], Training loss is 0.042276
# [Epoch 41 / 45], Validation loss is 1.354444, Top-5 accuracy is 0.887125, Top-1 accuracy is 0.646013
# [Epoch 42 / 45], Training loss is 0.042843
# [Epoch 42 / 45], Validation loss is 1.360579, Top-5 accuracy is 0.882810, Top-1 accuracy is 0.646013
# [Epoch 43 / 45], Training loss is 0.042355
# [Epoch 43 / 45], Validation loss is 1.356300, Top-5 accuracy is 0.886089, Top-1 accuracy is 0.643942
# [Epoch 44 / 45], Training loss is 0.042902
# [Epoch 44 / 45], Validation loss is 1.357695, Top-5 accuracy is 0.882810, Top-1 accuracy is 0.645323
# [Epoch 45 / 45], Training loss is 0.041266
# [Epoch 45 / 45], Validation loss is 1.352820, Top-5 accuracy is 0.886607, Top-1 accuracy is 0.646358

# %% [markdown]
# #### 3.2 Inspect the Accuracy

# %%
# !more .\Output\best_accuracy_ep.txt
# Out:
# Epoch  Accuracy
# ==================================================
#  5     0.545737
# 10     0.608043
# 15     0.619261
# 20     0.637038
# 25     0.639455
# 30     0.642734
# 35     0.647912
# 40     0.647912
# 45     0.647912

# %% [markdown]
# ### 4. Train with Random Initialized Weights

# %%
curr_best_acc = train_resnet_with_cub(num_epochs, best_fine_tune_lr, best_output_lr, pretrain=False)
# Out:
# ======================================================================
# Training with configuration (0.00050, 0.01000)
# [Epoch  1 / 45], Training loss is 5.624804
# [Epoch  1 / 45], Validation loss is 5.383454, Top-5 accuracy is 0.045047, Top-1 accuracy is 0.009665
# [Epoch  2 / 45], Training loss is 5.279906
# [Epoch  2 / 45], Validation loss is 5.273602, Top-5 accuracy is 0.059372, Top-1 accuracy is 0.011046
# [Epoch  3 / 45], Training loss is 5.127752
# [Epoch  3 / 45], Validation loss is 5.121473, Top-5 accuracy is 0.085088, Top-1 accuracy is 0.021056
# [Epoch  4 / 45], Training loss is 4.961903
# [Epoch  4 / 45], Validation loss is 5.093522, Top-5 accuracy is 0.111495, Top-1 accuracy is 0.030031
# [Epoch  5 / 45], Training loss is 4.834755
# [Epoch  5 / 45], Validation loss is 4.984315, Top-5 accuracy is 0.114946, Top-1 accuracy is 0.032102
# [Epoch  6 / 45], Training loss is 4.685044
# [Epoch  6 / 45], Validation loss is 4.907023, Top-5 accuracy is 0.133586, Top-1 accuracy is 0.034691
# [Epoch  7 / 45], Training loss is 4.592460
# [Epoch  7 / 45], Validation loss is 4.875474, Top-5 accuracy is 0.134277, Top-1 accuracy is 0.038661
# [Epoch  8 / 45], Training loss is 4.479224
# [Epoch  8 / 45], Validation loss is 4.863376, Top-5 accuracy is 0.145150, Top-1 accuracy is 0.041595
# [Epoch  9 / 45], Training loss is 4.362804
# [Epoch  9 / 45], Validation loss is 4.754123, Top-5 accuracy is 0.166379, Top-1 accuracy is 0.049707
# [Epoch 10 / 45], Training loss is 4.260786
# [Epoch 10 / 45], Validation loss is 4.748077, Top-5 accuracy is 0.179669, Top-1 accuracy is 0.057301
# [Epoch 11 / 45], Training loss is 4.170709
# [Epoch 11 / 45], Validation loss is 4.675679, Top-5 accuracy is 0.189679, Top-1 accuracy is 0.056610
# [Epoch 12 / 45], Training loss is 4.053266
# [Epoch 12 / 45], Validation loss is 4.683460, Top-5 accuracy is 0.207283, Top-1 accuracy is 0.062651
# [Epoch 13 / 45], Training loss is 3.971101
# [Epoch 13 / 45], Validation loss is 4.566968, Top-5 accuracy is 0.217294, Top-1 accuracy is 0.070245
# [Epoch 14 / 45], Training loss is 3.876974
# [Epoch 14 / 45], Validation loss is 4.594339, Top-5 accuracy is 0.209182, Top-1 accuracy is 0.061443
# [Epoch 15 / 45], Training loss is 3.794008
# [Epoch 15 / 45], Validation loss is 4.531930, Top-5 accuracy is 0.229030, Top-1 accuracy is 0.067138
# [Epoch 16 / 45], Training loss is 3.705685
# [Epoch 16 / 45], Validation loss is 4.509917, Top-5 accuracy is 0.236797, Top-1 accuracy is 0.066966
# [Epoch 17 / 45], Training loss is 3.610507
# [Epoch 17 / 45], Validation loss is 4.520299, Top-5 accuracy is 0.237487, Top-1 accuracy is 0.074905
# [Epoch 18 / 45], Training loss is 3.514683
# [Epoch 18 / 45], Validation loss is 4.518290, Top-5 accuracy is 0.242665, Top-1 accuracy is 0.081464
# [Epoch 19 / 45], Training loss is 3.440564
# [Epoch 19 / 45], Validation loss is 4.434694, Top-5 accuracy is 0.257680, Top-1 accuracy is 0.083880
# [Epoch 20 / 45], Training loss is 3.353920
# [Epoch 20 / 45], Validation loss is 4.393300, Top-5 accuracy is 0.260614, Top-1 accuracy is 0.091301
# [Epoch 21 / 45], Training loss is 3.266164
# [Epoch 21 / 45], Validation loss is 4.372448, Top-5 accuracy is 0.277183, Top-1 accuracy is 0.097515
# [Epoch 22 / 45], Training loss is 3.179033
# [Epoch 22 / 45], Validation loss is 4.375607, Top-5 accuracy is 0.274249, Top-1 accuracy is 0.095616
# [Epoch 23 / 45], Training loss is 3.101108
# [Epoch 23 / 45], Validation loss is 4.414753, Top-5 accuracy is 0.274249, Top-1 accuracy is 0.092682
# [Epoch 24 / 45], Training loss is 3.023283
# [Epoch 24 / 45], Validation loss is 4.322161, Top-5 accuracy is 0.288574, Top-1 accuracy is 0.101829
# [Epoch 25 / 45], Training loss is 2.948816
# [Epoch 25 / 45], Validation loss is 4.332945, Top-5 accuracy is 0.300311, Top-1 accuracy is 0.108043
# [Epoch 26 / 45], Training loss is 2.851015
# [Epoch 26 / 45], Validation loss is 4.338222, Top-5 accuracy is 0.297549, Top-1 accuracy is 0.106317
# [Epoch 27 / 45], Training loss is 2.766331
# [Epoch 27 / 45], Validation loss is 4.395675, Top-5 accuracy is 0.299103, Top-1 accuracy is 0.105627
# [Epoch 28 / 45], Training loss is 2.707349
# [Epoch 28 / 45], Validation loss is 4.294139, Top-5 accuracy is 0.308250, Top-1 accuracy is 0.113738
# [Epoch 29 / 45], Training loss is 2.613060
# [Epoch 29 / 45], Validation loss is 4.296993, Top-5 accuracy is 0.321712, Top-1 accuracy is 0.119261
# [Epoch 30 / 45], Training loss is 2.556002
# [Epoch 30 / 45], Validation loss is 4.274011, Top-5 accuracy is 0.315154, Top-1 accuracy is 0.123231
# [Epoch 31 / 45], Training loss is 2.445847
# [Epoch 31 / 45], Validation loss is 4.367623, Top-5 accuracy is 0.323093, Top-1 accuracy is 0.122195
# [Epoch 32 / 45], Training loss is 2.193718
# [Epoch 32 / 45], Validation loss is 4.097963, Top-5 accuracy is 0.351053, Top-1 accuracy is 0.138937
# [Epoch 33 / 45], Training loss is 2.120699
# [Epoch 33 / 45], Validation loss is 4.094420, Top-5 accuracy is 0.353297, Top-1 accuracy is 0.142561
# [Epoch 34 / 45], Training loss is 2.134916
# [Epoch 34 / 45], Validation loss is 4.097012, Top-5 accuracy is 0.355022, Top-1 accuracy is 0.142561
# [Epoch 35 / 45], Training loss is 2.111342
# [Epoch 35 / 45], Validation loss is 4.103550, Top-5 accuracy is 0.350880, Top-1 accuracy is 0.139800
# [Epoch 36 / 45], Training loss is 2.084024
# [Epoch 36 / 45], Validation loss is 4.092892, Top-5 accuracy is 0.358474, Top-1 accuracy is 0.141008
# [Epoch 37 / 45], Training loss is 2.092197
# [Epoch 37 / 45], Validation loss is 4.099917, Top-5 accuracy is 0.356403, Top-1 accuracy is 0.139109
# [Epoch 38 / 45], Training loss is 2.063371
# [Epoch 38 / 45], Validation loss is 4.086044, Top-5 accuracy is 0.352606, Top-1 accuracy is 0.141353
# [Epoch 39 / 45], Training loss is 2.055524
# [Epoch 39 / 45], Validation loss is 4.107226, Top-5 accuracy is 0.355885, Top-1 accuracy is 0.141353
# [Epoch 40 / 45], Training loss is 2.067021
# [Epoch 40 / 45], Validation loss is 4.094464, Top-5 accuracy is 0.356576, Top-1 accuracy is 0.138419
# [Epoch 41 / 45], Training loss is 2.033463
# [Epoch 41 / 45], Validation loss is 4.085805, Top-5 accuracy is 0.355713, Top-1 accuracy is 0.142043
# [Epoch 42 / 45], Training loss is 2.048870
# [Epoch 42 / 45], Validation loss is 4.098410, Top-5 accuracy is 0.357439, Top-1 accuracy is 0.141181
# [Epoch 43 / 45], Training loss is 2.028038
# [Epoch 43 / 45], Validation loss is 4.095101, Top-5 accuracy is 0.356231, Top-1 accuracy is 0.141698
# [Epoch 44 / 45], Training loss is 2.022618
# [Epoch 44 / 45], Validation loss is 4.097768, Top-5 accuracy is 0.357784, Top-1 accuracy is 0.143424
# [Epoch 45 / 45], Training loss is 1.991891
# [Epoch 45 / 45], Validation loss is 4.098324, Top-5 accuracy is 0.357611, Top-1 accuracy is 0.141181

# %% [markdown]
# ### 5. Test the trained model

# %%
MODEL_PATH = os.path.join("Output", "resnet18_cub.pth")
test_resnet_with_cub(DATA_PATH, MODEL_PATH)
# Out:
# 100%|██████████| 91/91 [02:40<00:00,  1.77s/it]
# For the class     Black_footed_Albatross     on the CUB dataset, Top-1 accuracy is 0.666667, Top-5 accuracy is 0.933333
# For the class        Laysan_Albatross        on the CUB dataset, Top-1 accuracy is 0.600000, Top-5 accuracy is 0.800000
# For the class        Sooty_Albatross         on the CUB dataset, Top-1 accuracy is 0.547297, Top-5 accuracy is 1.000000
# For the class       Groove_billed_Ani        on the CUB dataset, Top-1 accuracy is 0.600000, Top-5 accuracy is 0.966667
# For the class         Crested_Auklet         on the CUB dataset, Top-1 accuracy is 0.793103, Top-5 accuracy is 0.913793
# For the class          Least_Auklet          on the CUB dataset, Top-1 accuracy is 0.909091, Top-5 accuracy is 1.000000
# For the class        Parakeet_Auklet         on the CUB dataset, Top-1 accuracy is 0.782609, Top-5 accuracy is 0.956522
# For the class       Rhinoceros_Auklet        on the CUB dataset, Top-1 accuracy is 0.611111, Top-5 accuracy is 0.888889
# For the class        Brewer_Blackbird        on the CUB dataset, Top-1 accuracy is 0.364356, Top-5 accuracy is 0.760396
# For the class      Red_winged_Blackbird      on the CUB dataset, Top-1 accuracy is 0.666667, Top-5 accuracy is 0.900000
# For the class        Rusty_Blackbird         on the CUB dataset, Top-1 accuracy is 0.458515, Top-5 accuracy is 0.672489
# For the class    Yellow_headed_Blackbird     on the CUB dataset, Top-1 accuracy is 0.807692, Top-5 accuracy is 0.923077
# For the class            Bobolink            on the CUB dataset, Top-1 accuracy is 0.741379, Top-5 accuracy is 0.879310
# For the class         Indigo_Bunting         on the CUB dataset, Top-1 accuracy is 0.866667, Top-5 accuracy is 1.000000
# For the class         Lazuli_Bunting         on the CUB dataset, Top-1 accuracy is 0.842271, Top-5 accuracy is 0.921136
# For the class        Painted_Bunting         on the CUB dataset, Top-1 accuracy is 0.821429, Top-5 accuracy is 0.928571
# For the class            Cardinal            on the CUB dataset, Top-1 accuracy is 0.666667, Top-5 accuracy is 0.851852
# For the class        Spotted_Catbird         on the CUB dataset, Top-1 accuracy is 0.846154, Top-5 accuracy is 1.000000
# For the class          Gray_Catbird          on the CUB dataset, Top-1 accuracy is 0.620690, Top-5 accuracy is 0.896552
# For the class      Yellow_breasted_Chat      on the CUB dataset, Top-1 accuracy is 0.506569, Top-5 accuracy is 0.886131
# For the class         Eastern_Towhee         on the CUB dataset, Top-1 accuracy is 0.766667, Top-5 accuracy is 0.933333
# For the class        Chuck_will_Widow        on the CUB dataset, Top-1 accuracy is 0.576923, Top-5 accuracy is 1.000000
# For the class        Brandt_Cormorant        on the CUB dataset, Top-1 accuracy is 0.535774, Top-5 accuracy is 0.960067
# For the class      Red_faced_Cormorant       on the CUB dataset, Top-1 accuracy is 0.636364, Top-5 accuracy is 1.000000
# For the class       Pelagic_Cormorant        on the CUB dataset, Top-1 accuracy is 0.564103, Top-5 accuracy is 0.910256
# For the class        Bronzed_Cowbird         on the CUB dataset, Top-1 accuracy is 0.666667, Top-5 accuracy is 0.966667
# For the class         Shiny_Cowbird          on the CUB dataset, Top-1 accuracy is 0.244526, Top-5 accuracy is 0.795620
# For the class         Brown_Creeper          on the CUB dataset, Top-1 accuracy is 0.724138, Top-5 accuracy is 0.965517
# For the class         American_Crow          on the CUB dataset, Top-1 accuracy is 0.369919, Top-5 accuracy is 0.853659
# For the class           Fish_Crow            on the CUB dataset, Top-1 accuracy is 0.166667, Top-5 accuracy is 0.666667
# For the class      Black_billed_Cuckoo       on the CUB dataset, Top-1 accuracy is 0.666667, Top-5 accuracy is 0.933333
# For the class        Mangrove_Cuckoo         on the CUB dataset, Top-1 accuracy is 0.501031, Top-5 accuracy is 0.818557
# For the class      Yellow_billed_Cuckoo      on the CUB dataset, Top-1 accuracy is 0.517241, Top-5 accuracy is 0.862069
# For the class    Gray_crowned_Rosy_Finch     on the CUB dataset, Top-1 accuracy is 0.764706, Top-5 accuracy is 0.938824
# For the class          Purple_Finch          on the CUB dataset, Top-1 accuracy is 0.933333, Top-5 accuracy is 1.000000
# For the class        Northern_Flicker        on the CUB dataset, Top-1 accuracy is 0.679487, Top-5 accuracy is 0.923077
# For the class       Acadian_Flycatcher       on the CUB dataset, Top-1 accuracy is 0.206897, Top-5 accuracy is 0.793103
# For the class    Great_Crested_Flycatcher    on the CUB dataset, Top-1 accuracy is 0.541522, Top-5 accuracy is 0.776817
# For the class        Least_Flycatcher        on the CUB dataset, Top-1 accuracy is 0.275862, Top-5 accuracy is 0.689655
# For the class     Olive_sided_Flycatcher     on the CUB dataset, Top-1 accuracy is 0.532995, Top-5 accuracy is 0.784264
# For the class   Scissor_tailed_Flycatcher    on the CUB dataset, Top-1 accuracy is 0.766667, Top-5 accuracy is 0.900000
# For the class      Vermilion_Flycatcher      on the CUB dataset, Top-1 accuracy is 0.700000, Top-5 accuracy is 1.000000
# For the class   Yellow_bellied_Flycatcher    on the CUB dataset, Top-1 accuracy is 0.334243, Top-5 accuracy is 0.631651
# For the class          Frigatebird           on the CUB dataset, Top-1 accuracy is 0.733333, Top-5 accuracy is 0.933333
# For the class        Northern_Fulmar         on the CUB dataset, Top-1 accuracy is 0.685121, Top-5 accuracy is 0.880623
# For the class            Gadwall             on the CUB dataset, Top-1 accuracy is 0.800000, Top-5 accuracy is 0.933333
# For the class       American_Goldfinch       on the CUB dataset, Top-1 accuracy is 0.813278, Top-5 accuracy is 1.000000
# For the class       European_Goldfinch       on the CUB dataset, Top-1 accuracy is 0.900000, Top-5 accuracy is 0.966667
# For the class      Boat_tailed_Grackle       on the CUB dataset, Top-1 accuracy is 0.666667, Top-5 accuracy is 0.900000
# For the class          Eared_Grebe           on the CUB dataset, Top-1 accuracy is 0.800000, Top-5 accuracy is 0.966667
# For the class          Horned_Grebe          on the CUB dataset, Top-1 accuracy is 0.593361, Top-5 accuracy is 0.960581
# For the class       Pied_billed_Grebe        on the CUB dataset, Top-1 accuracy is 0.766667, Top-5 accuracy is 0.966667
# For the class         Western_Grebe          on the CUB dataset, Top-1 accuracy is 0.669550, Top-5 accuracy is 1.000000
# For the class         Blue_Grosbeak          on the CUB dataset, Top-1 accuracy is 0.766667, Top-5 accuracy is 0.933333
# For the class        Evening_Grosbeak        on the CUB dataset, Top-1 accuracy is 0.776423, Top-5 accuracy is 0.959350
# For the class         Pine_Grosbeak          on the CUB dataset, Top-1 accuracy is 0.833333, Top-5 accuracy is 1.000000
# For the class     Rose_breasted_Grosbeak     on the CUB dataset, Top-1 accuracy is 0.900000, Top-5 accuracy is 0.933333
# For the class        Pigeon_Guillemot        on the CUB dataset, Top-1 accuracy is 0.593151, Top-5 accuracy is 0.926027
# For the class        California_Gull         on the CUB dataset, Top-1 accuracy is 0.133333, Top-5 accuracy is 0.766667
# For the class      Glaucous_winged_Gull      on the CUB dataset, Top-1 accuracy is 0.302064, Top-5 accuracy is 0.767355
# For the class         Heermann_Gull          on the CUB dataset, Top-1 accuracy is 0.833333, Top-5 accuracy is 1.000000
# For the class          Herring_Gull          on the CUB dataset, Top-1 accuracy is 0.333333, Top-5 accuracy is 0.782051
# For the class           Ivory_Gull           on the CUB dataset, Top-1 accuracy is 0.733333, Top-5 accuracy is 0.933333
# For the class        Ring_billed_Gull        on the CUB dataset, Top-1 accuracy is 0.296460, Top-5 accuracy is 0.836283
# For the class       Slaty_backed_Gull        on the CUB dataset, Top-1 accuracy is 0.550000, Top-5 accuracy is 0.650000
# For the class          Western_Gull          on the CUB dataset, Top-1 accuracy is 0.733333, Top-5 accuracy is 0.866667
# For the class        Anna_Hummingbird        on the CUB dataset, Top-1 accuracy is 0.566667, Top-5 accuracy is 0.866667
# For the class   Ruby_throated_Hummingbird    on the CUB dataset, Top-1 accuracy is 0.500000, Top-5 accuracy is 0.900000
# For the class       Rufous_Hummingbird       on the CUB dataset, Top-1 accuracy is 0.511561, Top-5 accuracy is 0.924855
# For the class        Green_Violetear         on the CUB dataset, Top-1 accuracy is 1.000000, Top-5 accuracy is 1.000000
# For the class       Long_tailed_Jaeger       on the CUB dataset, Top-1 accuracy is 0.405109, Top-5 accuracy is 0.729927
# For the class        Pomarine_Jaeger         on the CUB dataset, Top-1 accuracy is 0.233333, Top-5 accuracy is 0.733333
# For the class            Blue_Jay            on the CUB dataset, Top-1 accuracy is 0.807692, Top-5 accuracy is 0.897436
# For the class          Florida_Jay           on the CUB dataset, Top-1 accuracy is 0.933333, Top-5 accuracy is 1.000000
# For the class           Green_Jay            on the CUB dataset, Top-1 accuracy is 0.941645, Top-5 accuracy is 0.970822
# For the class        Dark_eyed_Junco         on the CUB dataset, Top-1 accuracy is 0.833333, Top-5 accuracy is 0.933333
# For the class       Tropical_Kingbird        on the CUB dataset, Top-1 accuracy is 0.776817, Top-5 accuracy is 0.908304
# For the class         Gray_Kingbird          on the CUB dataset, Top-1 accuracy is 0.689655, Top-5 accuracy is 1.000000
# For the class       Belted_Kingfisher        on the CUB dataset, Top-1 accuracy is 0.606599, Top-5 accuracy is 0.893401
# For the class        Green_Kingfisher        on the CUB dataset, Top-1 accuracy is 0.600000, Top-5 accuracy is 0.866667
# For the class        Pied_Kingfisher         on the CUB dataset, Top-1 accuracy is 0.833333, Top-5 accuracy is 0.933333
# For the class       Ringed_Kingfisher        on the CUB dataset, Top-1 accuracy is 0.644670, Top-5 accuracy is 0.964467
# For the class   White_breasted_Kingfisher    on the CUB dataset, Top-1 accuracy is 0.866667, Top-5 accuracy is 0.966667
# For the class      Red_legged_Kittiwake      on the CUB dataset, Top-1 accuracy is 0.843077, Top-5 accuracy is 0.947692
# For the class          Horned_Lark           on the CUB dataset, Top-1 accuracy is 0.833333, Top-5 accuracy is 0.966667
# For the class          Pacific_Loon          on the CUB dataset, Top-1 accuracy is 0.757642, Top-5 accuracy is 1.000000
# For the class            Mallard             on the CUB dataset, Top-1 accuracy is 0.766667, Top-5 accuracy is 0.933333
# For the class       Western_Meadowlark       on the CUB dataset, Top-1 accuracy is 0.689655, Top-5 accuracy is 0.862069
# For the class        Hooded_Merganser        on the CUB dataset, Top-1 accuracy is 0.766667, Top-5 accuracy is 0.800000
# For the class     Red_breasted_Merganser     on the CUB dataset, Top-1 accuracy is 0.761538, Top-5 accuracy is 0.876923
# For the class          Mockingbird           on the CUB dataset, Top-1 accuracy is 0.366667, Top-5 accuracy is 0.766667
# For the class           Nighthawk            on the CUB dataset, Top-1 accuracy is 0.827791, Top-5 accuracy is 0.965558
# For the class        Clark_Nutcracker        on the CUB dataset, Top-1 accuracy is 0.900000, Top-5 accuracy is 1.000000
# For the class    White_breasted_Nuthatch     on the CUB dataset, Top-1 accuracy is 0.733333, Top-5 accuracy is 0.966667
# For the class        Baltimore_Oriole        on the CUB dataset, Top-1 accuracy is 0.776423, Top-5 accuracy is 0.922764
# For the class         Hooded_Oriole          on the CUB dataset, Top-1 accuracy is 0.633333, Top-5 accuracy is 0.800000
# For the class         Orchard_Oriole         on the CUB dataset, Top-1 accuracy is 0.656660, Top-5 accuracy is 0.739212
# For the class          Scott_Oriole          on the CUB dataset, Top-1 accuracy is 0.766667, Top-5 accuracy is 0.933333
# For the class            Ovenbird            on the CUB dataset, Top-1 accuracy is 0.756410, Top-5 accuracy is 0.910256
# For the class         Brown_Pelican          on the CUB dataset, Top-1 accuracy is 0.900000, Top-5 accuracy is 0.966667
# For the class         White_Pelican          on the CUB dataset, Top-1 accuracy is 0.823529, Top-5 accuracy is 1.000000
# For the class       Western_Wood_Pewee       on the CUB dataset, Top-1 accuracy is 0.233333, Top-5 accuracy is 0.600000
# For the class            Sayornis            on the CUB dataset, Top-1 accuracy is 0.366667, Top-5 accuracy is 0.900000
# For the class         American_Pipit         on the CUB dataset, Top-1 accuracy is 0.633333, Top-5 accuracy is 0.766667
# For the class         Whip_poor_Will         on the CUB dataset, Top-1 accuracy is 0.631579, Top-5 accuracy is 1.000000
# For the class         Horned_Puffin          on the CUB dataset, Top-1 accuracy is 0.800000, Top-5 accuracy is 0.933333
# For the class          Common_Raven          on the CUB dataset, Top-1 accuracy is 0.333333, Top-5 accuracy is 0.800000
# For the class       White_necked_Raven       on the CUB dataset, Top-1 accuracy is 0.558091, Top-5 accuracy is 0.829876
# For the class       American_Redstart        on the CUB dataset, Top-1 accuracy is 0.833333, Top-5 accuracy is 0.866667
# For the class           Geococcyx            on the CUB dataset, Top-1 accuracy is 0.868512, Top-5 accuracy is 0.948097
# For the class       Loggerhead_Shrike        on the CUB dataset, Top-1 accuracy is 0.400000, Top-5 accuracy is 0.933333
# For the class       Great_Grey_Shrike        on the CUB dataset, Top-1 accuracy is 0.626016, Top-5 accuracy is 0.922764
# For the class         Baird_Sparrow          on the CUB dataset, Top-1 accuracy is 0.850000, Top-5 accuracy is 1.000000
# For the class     Black_throated_Sparrow     on the CUB dataset, Top-1 accuracy is 0.633333, Top-5 accuracy is 0.800000
# For the class         Brewer_Sparrow         on the CUB dataset, Top-1 accuracy is 0.260674, Top-5 accuracy is 0.788764
# For the class        Chipping_Sparrow        on the CUB dataset, Top-1 accuracy is 0.400000, Top-5 accuracy is 0.800000
# For the class      Clay_colored_Sparrow      on the CUB dataset, Top-1 accuracy is 0.498824, Top-5 accuracy is 0.877647
# For the class         House_Sparrow          on the CUB dataset, Top-1 accuracy is 0.333333, Top-5 accuracy is 0.633333
# For the class         Field_Sparrow          on the CUB dataset, Top-1 accuracy is 0.495050, Top-5 accuracy is 0.900990
# For the class          Fox_Sparrow           on the CUB dataset, Top-1 accuracy is 0.500000, Top-5 accuracy is 0.733333
# For the class      Grasshopper_Sparrow       on the CUB dataset, Top-1 accuracy is 0.387283, Top-5 accuracy is 0.731214
# For the class         Harris_Sparrow         on the CUB dataset, Top-1 accuracy is 0.733333, Top-5 accuracy is 0.900000
# For the class        Henslow_Sparrow         on the CUB dataset, Top-1 accuracy is 0.666667, Top-5 accuracy is 0.966667
# For the class        Le_Conte_Sparrow        on the CUB dataset, Top-1 accuracy is 0.551724, Top-5 accuracy is 0.862069
# For the class        Lincoln_Sparrow         on the CUB dataset, Top-1 accuracy is 0.482759, Top-5 accuracy is 0.862069
# For the class  Nelson_Sharp_tailed_Sparrow   on the CUB dataset, Top-1 accuracy is 0.480392, Top-5 accuracy is 0.803922
# For the class        Savannah_Sparrow        on the CUB dataset, Top-1 accuracy is 0.533333, Top-5 accuracy is 0.766667
# For the class        Seaside_Sparrow         on the CUB dataset, Top-1 accuracy is 0.540000, Top-5 accuracy is 0.780000
# For the class          Song_Sparrow          on the CUB dataset, Top-1 accuracy is 0.600000, Top-5 accuracy is 0.866667
# For the class          Tree_Sparrow          on the CUB dataset, Top-1 accuracy is 0.561947, Top-5 accuracy is 0.800885
# For the class         Vesper_Sparrow         on the CUB dataset, Top-1 accuracy is 0.366667, Top-5 accuracy is 0.866667
# For the class     White_crowned_Sparrow      on the CUB dataset, Top-1 accuracy is 0.730769, Top-5 accuracy is 0.935897
# For the class     White_throated_Sparrow     on the CUB dataset, Top-1 accuracy is 0.700000, Top-5 accuracy is 0.900000
# For the class      Cape_Glossy_Starling      on the CUB dataset, Top-1 accuracy is 0.905109, Top-5 accuracy is 1.000000
# For the class          Bank_Swallow          on the CUB dataset, Top-1 accuracy is 0.466667, Top-5 accuracy is 0.700000
# For the class          Barn_Swallow          on the CUB dataset, Top-1 accuracy is 0.612717, Top-5 accuracy is 0.849711
# For the class         Cliff_Swallow          on the CUB dataset, Top-1 accuracy is 0.633333, Top-5 accuracy is 0.900000
# For the class          Tree_Swallow          on the CUB dataset, Top-1 accuracy is 0.633333, Top-5 accuracy is 0.800000
# For the class        Scarlet_Tanager         on the CUB dataset, Top-1 accuracy is 0.933333, Top-5 accuracy is 1.000000
# For the class         Summer_Tanager         on the CUB dataset, Top-1 accuracy is 0.933333, Top-5 accuracy is 1.000000
# For the class           Artic_Tern           on the CUB dataset, Top-1 accuracy is 0.591264, Top-5 accuracy is 1.000000
# For the class           Black_Tern           on the CUB dataset, Top-1 accuracy is 0.366667, Top-5 accuracy is 0.733333
# For the class          Caspian_Tern          on the CUB dataset, Top-1 accuracy is 0.465517, Top-5 accuracy is 0.942529
# For the class          Common_Tern           on the CUB dataset, Top-1 accuracy is 0.233333, Top-5 accuracy is 0.766667
# For the class          Elegant_Tern          on the CUB dataset, Top-1 accuracy is 0.401747, Top-5 accuracy is 0.831878
# For the class         Forsters_Tern          on the CUB dataset, Top-1 accuracy is 0.366667, Top-5 accuracy is 0.833333
# For the class           Least_Tern           on the CUB dataset, Top-1 accuracy is 0.962882, Top-5 accuracy is 0.962882
# For the class      Green_tailed_Towhee       on the CUB dataset, Top-1 accuracy is 0.766667, Top-5 accuracy is 0.933333
# For the class         Brown_Thrasher         on the CUB dataset, Top-1 accuracy is 0.702970, Top-5 accuracy is 0.984158
# For the class         Sage_Thrasher          on the CUB dataset, Top-1 accuracy is 0.700000, Top-5 accuracy is 0.900000
# For the class       Black_capped_Vireo       on the CUB dataset, Top-1 accuracy is 0.809524, Top-5 accuracy is 0.952381
# For the class       Blue_headed_Vireo        on the CUB dataset, Top-1 accuracy is 0.753846, Top-5 accuracy is 0.876923
# For the class       Philadelphia_Vireo       on the CUB dataset, Top-1 accuracy is 0.620690, Top-5 accuracy is 0.931034
# For the class         Red_eyed_Vireo         on the CUB dataset, Top-1 accuracy is 0.500000, Top-5 accuracy is 0.760000
# For the class         Warbling_Vireo         on the CUB dataset, Top-1 accuracy is 0.400000, Top-5 accuracy is 0.733333
# For the class        White_eyed_Vireo        on the CUB dataset, Top-1 accuracy is 0.530973, Top-5 accuracy is 0.827434
# For the class     Yellow_throated_Vireo      on the CUB dataset, Top-1 accuracy is 0.517241, Top-5 accuracy is 0.758621
# For the class      Bay_breasted_Warbler      on the CUB dataset, Top-1 accuracy is 0.740664, Top-5 accuracy is 0.842324
# For the class    Black_and_white_Warbler     on the CUB dataset, Top-1 accuracy is 0.800000, Top-5 accuracy is 0.933333
# For the class  Black_throated_Blue_Warbler   on the CUB dataset, Top-1 accuracy is 0.837168, Top-5 accuracy is 1.000000
# For the class      Blue_winged_Warbler       on the CUB dataset, Top-1 accuracy is 0.566667, Top-5 accuracy is 0.833333
# For the class         Canada_Warbler         on the CUB dataset, Top-1 accuracy is 0.573604, Top-5 accuracy is 0.822335
# For the class        Cape_May_Warbler        on the CUB dataset, Top-1 accuracy is 0.666667, Top-5 accuracy is 0.966667
# For the class        Cerulean_Warbler        on the CUB dataset, Top-1 accuracy is 0.866667, Top-5 accuracy is 1.000000
# For the class     Chestnut_sided_Warbler     on the CUB dataset, Top-1 accuracy is 0.677665, Top-5 accuracy is 0.857868
# For the class     Golden_winged_Warbler      on the CUB dataset, Top-1 accuracy is 0.758621, Top-5 accuracy is 0.931034
# For the class         Hooded_Warbler         on the CUB dataset, Top-1 accuracy is 0.645329, Top-5 accuracy is 0.761246
# For the class        Kentucky_Warbler        on the CUB dataset, Top-1 accuracy is 0.793103, Top-5 accuracy is 0.931034
# For the class        Magnolia_Warbler        on the CUB dataset, Top-1 accuracy is 0.866051, Top-5 accuracy is 1.000000
# For the class        Mourning_Warbler        on the CUB dataset, Top-1 accuracy is 0.500000, Top-5 accuracy is 0.866667
# For the class         Myrtle_Warbler         on the CUB dataset, Top-1 accuracy is 0.746725, Top-5 accuracy is 0.849345
# For the class       Nashville_Warbler        on the CUB dataset, Top-1 accuracy is 0.733333, Top-5 accuracy is 1.000000
# For the class     Orange_crowned_Warbler     on the CUB dataset, Top-1 accuracy is 0.367816, Top-5 accuracy is 0.626437
# For the class          Palm_Warbler          on the CUB dataset, Top-1 accuracy is 0.733333, Top-5 accuracy is 0.866667
# For the class          Pine_Warbler          on the CUB dataset, Top-1 accuracy is 0.600000, Top-5 accuracy is 0.838462
# For the class        Prairie_Warbler         on the CUB dataset, Top-1 accuracy is 0.866667, Top-5 accuracy is 1.000000
# For the class      Prothonotary_Warbler      on the CUB dataset, Top-1 accuracy is 0.896675, Top-5 accuracy is 1.000000
# For the class        Swainson_Warbler        on the CUB dataset, Top-1 accuracy is 0.500000, Top-5 accuracy is 0.730769
# For the class       Tennessee_Warbler        on the CUB dataset, Top-1 accuracy is 0.413793, Top-5 accuracy is 0.655172
# For the class         Wilson_Warbler         on the CUB dataset, Top-1 accuracy is 0.755474, Top-5 accuracy is 0.905109
# For the class      Worm_eating_Warbler       on the CUB dataset, Top-1 accuracy is 0.758621, Top-5 accuracy is 0.896552
# For the class         Yellow_Warbler         on the CUB dataset, Top-1 accuracy is 0.757642, Top-5 accuracy is 0.971616
# For the class      Northern_Waterthrush      on the CUB dataset, Top-1 accuracy is 0.600000, Top-5 accuracy is 0.966667
# For the class     Louisiana_Waterthrush      on the CUB dataset, Top-1 accuracy is 0.692140, Top-5 accuracy is 0.943231
# For the class        Bohemian_Waxwing        on the CUB dataset, Top-1 accuracy is 0.700000, Top-5 accuracy is 0.933333
# For the class         Cedar_Waxwing          on the CUB dataset, Top-1 accuracy is 0.798851, Top-5 accuracy is 0.959770
# For the class American_Three_toed_Woodpecker on the CUB dataset, Top-1 accuracy is 0.750000, Top-5 accuracy is 1.000000
# For the class      Pileated_Woodpecker       on the CUB dataset, Top-1 accuracy is 0.866667, Top-5 accuracy is 0.966667
# For the class     Red_bellied_Woodpecker     on the CUB dataset, Top-1 accuracy is 0.923077, Top-5 accuracy is 1.000000
# For the class    Red_cockaded_Woodpecker     on the CUB dataset, Top-1 accuracy is 0.896552, Top-5 accuracy is 0.965517
# For the class     Red_headed_Woodpecker      on the CUB dataset, Top-1 accuracy is 0.800000, Top-5 accuracy is 0.900000
# For the class        Downy_Woodpecker        on the CUB dataset, Top-1 accuracy is 0.766667, Top-5 accuracy is 0.966667
# For the class          Bewick_Wren           on the CUB dataset, Top-1 accuracy is 0.464602, Top-5 accuracy is 0.800885
# For the class          Cactus_Wren           on the CUB dataset, Top-1 accuracy is 0.833333, Top-5 accuracy is 0.933333
# For the class         Carolina_Wren          on the CUB dataset, Top-1 accuracy is 0.717949, Top-5 accuracy is 0.884615
# For the class           House_Wren           on the CUB dataset, Top-1 accuracy is 0.466667, Top-5 accuracy is 0.766667
# For the class           Marsh_Wren           on the CUB dataset, Top-1 accuracy is 0.660584, Top-5 accuracy is 0.850365
# For the class           Rock_Wren            on the CUB dataset, Top-1 accuracy is 0.566667, Top-5 accuracy is 0.766667
# For the class          Winter_Wren           on the CUB dataset, Top-1 accuracy is 0.812139, Top-5 accuracy is 0.962428
# For the class      Common_Yellowthroat       on the CUB dataset, Top-1 accuracy is 0.833333, Top-5 accuracy is 0.900000
# ========================================================================================================================
# For the best model on the CUB dataset, Total Top-1 accuracy is 0.647912, Total Top-5 accuracy is 0.886089
